# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # for visualizasion
import seaborn as sns # for visualizasion

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
sns.scatterplot(x=df['cgpa'], y=df['resume_score'], hue=df['placed'])
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# df[['cgpa', 'resume_score']] = scaler.fit_transform(df[['cgpa', 'resume_score']])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[['cgpa', 'resume_score']] = scaler.fit_transform(df[['cgpa', 'resume_score']])

# %%
sns.scatterplot(x=df['cgpa'], y=df['resume_score'], hue=df['placed'])
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
# X = df[['cgpa', 'resume_score']]
# y = df['placed']

# %%
X = df.iloc[:, 0:2]
y = df.iloc[:, -1]

# %%
X
# Out:
#         cgpa  resume_score
# 0   1.075620     -0.421156
# 1  -0.693433     -1.806202
# 2   1.192360      1.979589
# 3  -0.055855      0.348313
# 4   0.518862      0.379092
# ..       ...           ...
# 95 -0.549753     -0.564791
# 96  1.156440      0.851033
# 97 -0.262395      0.871553
# 98  1.075620     -1.334260
# 99 -0.765273     -0.328820
#
# [100 rows x 2 columns]

# %%
import random

lr = 0.1
epochs = 1000
w1 = random.uniform(-1, 1)
w2 = random.uniform(-1, 1)
b = random.uniform(-1, 1)

# %%
w1
# Out:
# 0.3822278325521271

# %%
w2
# Out:
# 0.30134015771374334

# %%
b
# Out:
# 0.41968672722248423

# %%
w1 = .53333333345

# %%
w2 = .5

# %%
b = -.01943534636

# %%
def step_function(z):
  if z >= 0:
    return 1
  else:
    return 0

# %%
def predict(x1, x2, w1, w2, b):
        z = w1 * x1 + w2 * x2 + b
        return step_function(z)

# %%
def fit(X, y):
  for epoch in range(epoch):
    # Shuffle Data Every Epoch
    #indices = np.random.permutation(len(X))
    #X = X[indices]
    #y = y[indices]
    for i in range(len(X)):
      x1, x2 = X.iloc[i]
      y_pred = predict(x1, x2, w1, w2, b)
      y_actual = y[i]

      error = y_actual - y_pred

      w1 += lr * error * x1
      w2 += lr * error * x2
      b += lr * error
    print(f"Epoch {epoch+1} done")

# %% [markdown]
# Testing data diye age accuracy check kori

# %%
# mis_idx = []

# for i in range(len(X)):
#     if predict(x1, x2, w1, w2, b) != y[i]:
#         mis_idx.append(i)

# # remove persistent errors
# X_clean = np.delete(X, mis_idx, axis=0)
# y_clean = np.delete(y, mis_idx, axis=0)

# %%
correct_count = 0
for i in range(len(X)):
  x1, x2 = X.iloc[i]
  pred = predict(x1, x2, w1, w2, b) # Corrected: Use .iloc for positional indexing
  if pred == y[i]:
    correct_count += 1

print(f"Accuracy: {correct_count/len(X)}")
# Out:
# Accuracy: 0.78

# %%
w1
# Out:
# 0.3822278325521271

# %%
w2
# Out:
# 0.30134015771374334

# %%
b
# Out:
# 0.41968672722248423
